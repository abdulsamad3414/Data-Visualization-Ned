# %% [markdown]
# key points
# 1. object orietnted programing
#
# 2. Dta strutured and Algorithm
# 3. Methode is the function which return some thing .plt means plot bun gaya
# 4. attribute just return
# 5. plt ,pd these are alisce
# 6. numpy perfom numerical python
# 7. book link for python data science (https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb)
# 8. with in a single list string ,int,bool and float all can be stored at a time.
# 9. numpy ki apni array bi create hojati ha (x = np.linspace(0, 10, 100)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Setting Styles
plt.style.use('classic')

# %%
# file: myplot.py 
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()  # yahan ya object create hogaya ab is par kam karna ha 
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# Object-oriented interface this is anther methode

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Use the updated Seaborn style name:
plt.style.use('seaborn-v0_8-whitegrid')  
import numpy as np

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 20) # generate 30 dataoints between 0 and 10
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
x = np.linspace(0, 10, 300) # generate 300 dataoints between 0 and 10
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.RandomState(0) # this is fixed so that ham next day bi wohi sub points rahain 
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(1), rng.rand(1), marker, # yahan 1 or 1 same rukhna ha 
             label="marker='{marker}'")
plt.legend(numpoints=1,fontsize=13);
plt.xlim(0, 1.8);

# %% [markdown]
# iterators :chairs jumping pads hain agay agay jana hota ha

# %%
x = np.linspace(0, 10, 20) # generate 30 dataoints between 0 and 10
y = np.sin(x)
plt.plot(x, y, '-ok');

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100) # yahan say values choti atain hain due to which we increase the amplitute

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3)
plt.colorbar();  # show color scale

# %% [markdown]
# jo change nea ho suktay wo attributes hain
# 1. jo ka change ho saukta ha wo method hain
# 2. linraries contains mulpliple methode and objects
# 3. continue data frame:

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[1], features[0], alpha=0.2,
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
